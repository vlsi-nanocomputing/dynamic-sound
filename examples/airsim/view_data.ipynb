# %% [markdown]
# # Data conversion for DynamicSound simulator

# %%
from data_converter import data_converter
data_dir = './data/run1/'
data_converter(data_dir)
# Out:
# destination folder: ./data/run1/converted
# ...
# camera_path.csv: 100%|██████████| 30/30 [00:00<00:00, 159884.52it/s]

# %% [markdown]
# # Data visualization

# %%
import pickle
import json
import os
import matplotlib.pyplot as plt
import numpy as np
from enum import Enum
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# %%
class Data(Enum):
    TIMESTAMP = 1
    DRONE_POSITION = 2 # will collect the drone's current position [x, y, z] at each frame
    DRONE_ROTATION = 3
    DRONE_VELOCITY = 4 # will collect the drone's current velocity [vx, vy, vz] at each frame
    CAMERA_POSITION = 5
    CAMERA_ROTATION = 6
    BGR = 7 # will collect BGR (not RGB) images from the scene at each frame
    ROTOR_SPEED = 8

# %%
data_dir = './data/run1/'
frames_path = os.path.join(data_dir, 'frames.p')
params_path = os.path.join(data_dir, 'params.json')

frames = pickle.load(open(frames_path, 'rb'))
params = json.load(open(params_path, 'r'))

# helper functions
def bgr_rgb(bgr):
    b = bgr[:, :, 0].copy()
    g = bgr[:, :, 1].copy()
    r = bgr[:, :, 2].copy()
    rgb = np.stack([r, g, b], axis=2)
    return rgb

images = []
for frame_idx, frame in enumerate(frames):
    if Data.BGR.name in frame:
        bgr = frame[Data.BGR.name]
        rgb = bgr_rgb(bgr)
        images.append(rgb)

fig, ax = plt.subplots()
img = ax.imshow(images[0], animated=True)

def update(frame):
    img.set_array(images[frame])
    return [img]

ani = FuncAnimation(fig, update, frames=len(images), interval=1000, blit=True, repeat=True)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
data_dir = './data/run1/'
frames_path = os.path.join(data_dir, 'frames.p')
params_path = os.path.join(data_dir, 'params.json')

frames = pickle.load(open(frames_path, 'rb'))
params = json.load(open(params_path, 'r'))

# helper functions
def bgr_rgb(bgr):
    b = bgr[:, :, 0].copy()
    g = bgr[:, :, 1].copy()
    r = bgr[:, :, 2].copy()
    rgb = np.stack([r, g, b], axis=2)
    return rgb

for frame_idx, frame in enumerate(frames):
    print('FRAME', frame_idx + 1)
    if Data.TIMESTAMP.name in frame:
        timestamp = frame[Data.TIMESTAMP.name]
    if Data.DRONE_POSITION.name in frame:
        x, y, z = frame[Data.DRONE_POSITION.name]
        print(f'drone position: [{x:.2f}, {y:.2f}, {z:.2f}] meters')
    if Data.DRONE_ROTATION.name in frame:
        w, x, y, z = frame[Data.DRONE_ROTATION.name]
        print(f'drone rotation: [{w:.2f}, {x:.2f}, {y:.2f}, {z:.2f}] quaternion')
    if Data.DRONE_VELOCITY.name in frame:
        vx, vy, vz = frame[Data.DRONE_VELOCITY.name]
        print(f'velocity: [{vx:.2f}, {vy:.2f}, {vz:.2f}] meters/sec')
    if Data.CAMERA_POSITION.name in frame:
        x, y, z = frame[Data.CAMERA_POSITION.name]
        print(f'camera position: [{x:.2f}, {y:.2f}, {z:.2f}] meters')
    if Data.CAMERA_ROTATION.name in frame:
        w, x, y, z = frame[Data.CAMERA_ROTATION.name]
        print(f'camera rotation: [{w:.2f}, {x:.2f}, {y:.2f}, {z:.2f}] quaternion')
    if Data.ROTOR_SPEED.name in frame:
        rotors = frame[Data.ROTOR_SPEED.name]
        print(f'rotor speed: [{[rotor["speed"] for rotor in rotors]}] rad/s')
    if Data.BGR.name in frame:
        bgr = frame[Data.BGR.name]
        rgb = bgr_rgb(bgr)
        plt.imshow(rgb)
        plt.title('RGB')
        plt.axis('off')
        plt.show()

print('USER SET PARAMETERS:', params)
# Out:
# FRAME 1
# drone position: [3.00, 0.00, 0.00] meters
# drone rotation: [1.00, -0.00, -0.00, -0.00] quaternion
# velocity: [-0.00, 0.00, -0.10] meters/sec
# camera position: [-6.00, -4.00, -1.00] meters
# camera rotation: [0.98, -0.02, 0.13, 0.17] quaternion
# rotor speed: [[644.5022583007812, 644.4475708007812, 644.514404296875, 644.4354248046875]] rad/s
# FRAME 2
# drone position: [3.03, 0.05, -2.96] meters
# drone rotation: [0.99, 0.12, -0.08, 0.00] quaternion
# velocity: [0.24, 0.35, -4.47] meters/sec
# camera position: [-6.00, -4.00, -1.00] meters
# camera rotation: [0.98, -0.02, 0.13, 0.17] quaternion
# rotor speed: [[508.4054870605469, 500.9761657714844, 505.3250427246094, 506.7896728515625]] rad/s
# FRAME 3
# drone position: [4.00, 1.40, -5.28] meters
# drone rotation: [0.99, 0.12, -0.08, 0.00] quaternion
# velocity: [1.78, 2.47, -0.69] meters/sec
# camera position: [-6.00, -4.00, -1.00] meters
# camera rotation: [0.98, -0.02, 0.13, 0.17] quaternion
# ...
